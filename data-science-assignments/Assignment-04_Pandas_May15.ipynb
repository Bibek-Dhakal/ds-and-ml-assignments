# %% [markdown]
# ### **Coding Assignment: Data Exploration and Visualization Using Pandas**
#
# ### **Dataset 01:**
# Use the [Iris Species dataset](https://www.kaggle.com/uciml/iris) from Kaggle, which contains measurements of different species of iris flowers.

# %% [markdown]
# #### **Instructions:**
#
# 1. **Importing the Dataset:**
#    - Load the dataset into a pandas DataFrame.
#    - Display the first 5 rows of the dataset.

# %%
import pandas as pd

# Load the dataset
iris_df = pd.read_csv('datasets/iris.csv')

iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 2. **Basic Data Exploration:**
#    - **Data Summary:**
#      - Display basic information about the dataset, including the number of rows and columns, data types of each column, and memory usage.
#      - Generate descriptive statistics for the numerical columns (e.g., mean, median, standard deviation).
#    - **Check for Missing Values:**
#      - Identify any missing values in the dataset and explain how you would handle them if there were any.
#    - **Value Counts:**
#      - Display the count of each unique species in the `species` column.

# %%
# Data Summary
print("Dataset Information:")
iris_df.info()
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
# Data Descriptive Statistics
print("\nDescriptive Statistics:")
iris_df.describe()
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
# check missing values
print("\nMissing Values:")
iris_df.isnull().sum()
# Out:
# Missing Values:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# value counts for species
print("\nValue Counts for unique values for Species:")
iris_df['Species'].unique().value_counts()
# Out:
# Value Counts for unique values for Species:
# Iris-setosa        1
# Iris-versicolor    1
# Iris-virginica     1
# Name: count, dtype: int64

# %% [markdown]
# 3. **Filtering and Sorting:**
#    - Filter the dataset to show only the rows where the `sepal_length` is greater than 5.0.
#    - Sort the filtered dataset by `petal_length` in descending order.

# %%
# Filter the dataset
filtered_iris = iris_df[iris_df['SepalLengthCm'] > 5.0]
filtered_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [118 rows x 6 columns]

# %%
# sort the filtered dataset
sorted_filtered_iris = filtered_iris.sort_values(by='PetalLengthCm', ascending=False)
sorted_filtered_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 122  123            7.7           2.8            6.7           2.0
# 105  106            7.6           3.0            6.6           2.1
# 131  132            7.9           3.8            6.4           2.0
# ..   ...            ...           ...            ...           ...
# 28    29            5.2           3.4            1.4           0.2
# 33    34            5.5           4.2            1.4           0.2
# 16    17            5.4           3.9            1.3           0.4
# 36    37            5.5           3.5            1.3           0.2
# 14    15            5.8           4.0            1.2           0.2
#
#             Species
# 118  Iris-virginica
# 117  Iris-virginica
# 122  Iris-virginica
# 105  Iris-virginica
# 131  Iris-virginica
# ..              ...
# 28      Iris-setosa
# 33      Iris-setosa
# 16      Iris-setosa
# 36      Iris-setosa
# 14      Iris-setosa
#
# [118 rows x 6 columns]

# %% [markdown]
# 5. **Creating New Columns:**
#    - Create a new column called `sepal_petal_ratio` which is the ratio of `sepal_length` to `petal_length`.

# %%
# Create a new column for sepal to petal ratio
iris_df['sepal_petal_ratio'] = iris_df['SepalLengthCm'] / iris_df['PetalLengthCm']
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_petal_ratio
# 0           3.642857
# 1           3.500000
# 2           3.615385
# 3           3.066667
# 4           3.571429

# %% [markdown]
# 6. **Data Visualization:**
#    - **Histogram:**
#      - Create a histogram to visualize the distribution of `sepal_length` values.
#    - **Scatter Plot:**
#      - Create a scatter plot with `sepal_length` on the x-axis and `petal_length` on the y-axis. Use different colors to represent different species.
#    - **Box Plot:**
#      - Create a box plot for the `sepal_width` values, grouped by `species`.

# %%
import matplotlib.pyplot as plt

# histogram for sepal length
plt.figure(figsize=(8, 6))
plt.hist(iris_df['SepalLengthCm'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# scatter plot for sepal length vs petal length
plt.figure(figsize=(8, 6))
species = iris_df['Species'].unique()
colors = ['red', 'green', 'blue']
for i, specie in enumerate(species):
    subset = iris_df[iris_df['Species'] == specie]
    plt.scatter(subset['SepalLengthCm'], subset['PetalLengthCm'], color=colors[i], label=specie)
plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.grid()
plt.show()

# %%
# box plot for sepal width grouped by species
plt.figure(figsize=(8, 6))
iris_df.boxplot(column='SepalWidthCm', by='Species', grid=False)
plt.title('Box Plot of Sepal Width by Species')
plt.suptitle('')
plt.xlabel('Species')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %% [markdown]
# 7. **Correlation Matrix**
#    - Calculate the correlation matrix for the numerical features and create a heatmap to visualize the correlations using `seaborn`.

# %%
import seaborn as sns

# correlation matrix
numeric_cols = iris_df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_cols.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### **Dataset 02 :** [House Prices Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)
#
# The dataset includes 79 explanatory variables that describe aspects of residential homes.
#
# #### **Instructions**:
# - Use Python and Jupyter Notebook to solve the questions.
# - Ensure your code is efficient, well-commented, and follows best practices for handling missing data and outliers.
# - Use appropriate visualizations where needed and include explanations for your analysis.

# %% [markdown]
# ### **Problem 1: Data Exploration with Pandas**
# 1. Load the House Prices dataset using Pandas and perform initial exploration:
#    - Display the first and last 5 rows.
#    - Display the **data types** of each column.
#    - Check for **missing values** and calculate the percentage of missing data for each column.
#    - Summarize the **statistical properties** of the numerical columns using `describe()`.
#
# 2. Based on the dataset, identify the following:
#    - Columns that are **categorical** and **numerical**.
#    - Any potential **outliers** in the numerical columns (use visualizations like boxplots).

# %%
import pandas as pd

# Load the dataset
house_prices_df = pd.read_csv('datasets/house-price/train.csv')
house_prices_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# Display the last 5 rows
house_prices_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %%
# Display data types of each column
print("Data Types of Each Column:")
house_prices_df.dtypes
# Out:
# Data Types of Each Column:
# Id                 int64
# MSSubClass         int64
# MSZoning             str
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType             str
# SaleCondition        str
# SalePrice          int64
# Length: 81, dtype: object

# %%
# check for missing values and calculate percentage of missing data
missing_values = house_prices_df.isnull().sum()
missing_percentage = (missing_values / len(house_prices_df)) * 100
missing_data_summary = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})
print("\nMissing Data Summary:")
missing_data_summary
# Out:
# Missing Data Summary:
#                Missing Values  Percentage
# Id                          0    0.000000
# MSSubClass                  0    0.000000
# MSZoning                    0    0.000000
# LotFrontage               259   17.739726
# LotArea                     0    0.000000
# ...                       ...         ...
# MoSold                      0    0.000000
# YrSold                      0    0.000000
# SaleType                    0    0.000000
# SaleCondition               0    0.000000
# SalePrice                   0    0.000000
#
# [81 rows x 2 columns]

# %%
# Summarize statistical properties of numerical columns
print("\nStatistical Properties of Numerical Columns:")
house_prices_df.describe()
# Out:
# Statistical Properties of Numerical Columns:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
# Identify categorical and numerical columns
categorical_columns = house_prices_df.select_dtypes(include=['str']).columns
numerical_columns = house_prices_df.select_dtypes(include=['float64', 'int64']).columns
print("\nCategorical Columns:")
print(categorical_columns)
print("\nNumerical Columns:")
print(numerical_columns)
# Out:
# Categorical Columns:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='str')
#
# Numerical Columns:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'Price_Per_SqFt'],
#       dtype='str')

# %%
# Visualize potential outliers using boxplots for numerical columns
import matplotlib.pyplot as plt

for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    house_prices_df.boxplot(column=column)
    plt.title(f'Box Plot for {column}')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ### **Problem 2: Data Manipulation with Pandas**
# 1. Filter the dataset to include only houses where the **SalePrice** is above the **90th percentile**.
# 2. Create a new **calculated column**: `Price_Per_SqFt = SalePrice / GrLivArea`.
# 3. **Group the data** by `Neighborhood` and calculate the **mean** and **median** for `SalePrice`.
# 4. Sort the dataset by `Price_Per_SqFt` and display the **top 10 rows**.

# %%
# Filter the dataset for houses with SalePrice above the 90th percentile
sale_price_90th_percentile = house_prices_df['SalePrice'].quantile(0.9)
filtered_houses = house_prices_df[house_prices_df['SalePrice'] > sale_price_90th_percentile]
filtered_houses
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1403  1404          20       RL         49.0    15256   Pave   NaN      IR1
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 6            Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 11           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 13           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 20           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 27           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# ...          ...       ...  ...      ...    ...   ...         ...     ...
# 1403         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1417         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1437         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1442         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1451         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 6         8   2007        WD         Normal     307000
# 11        7   2006       New        Partial     345000
# 13        8   2007       New        Partial     279500
# 20       11   2006       New        Partial     325300
# 27        5   2010        WD         Normal     306000
# ...     ...    ...       ...            ...        ...
# 1403      8   2007        WD         Normal     282922
# 1417      5   2009        WD         Normal     340000
# 1437     11   2008       New        Partial     394617
# 1442      4   2009        WD         Normal     310000
# 1451      5   2009       New        Partial     287090
#
# [145 rows x 81 columns]

# %%
# Create a new calculated column for Price Per SqFt
house_prices_df['Price_Per_SqFt'] = house_prices_df['SalePrice'] / house_prices_df['GrLivArea']
house_prices_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...    NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...    NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...    NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  Price_Per_SqFt
# 0       WD         Normal     208500      121.929825
# 1       WD         Normal     181500      143.819334
# 2       WD         Normal     223500      125.139978
# 3       WD        Abnorml     140000       81.537566
# 4       WD         Normal     250000      113.739763
#
# [5 rows x 82 columns]

# %%
# Group the data by Neighborhood and calculate mean and median for SalePrice
neighborhood_grouped = house_prices_df.groupby('Neighborhood')['SalePrice'].agg(['mean', 'median'])
print("\nMean and Median SalePrice by Neighborhood:")
neighborhood_grouped
# Out:
# Mean and Median SalePrice by Neighborhood:
#                        mean    median
# Neighborhood
# Blmngtn       194870.882353  191000.0
# Blueste       137500.000000  137500.0
# BrDale        104493.750000  106000.0
# BrkSide       124834.051724  124300.0
# ClearCr       212565.428571  200250.0
# CollgCr       197965.773333  197200.0
# Crawfor       210624.725490  200624.0
# Edwards       128219.700000  121750.0
# Gilbert       192854.506329  181000.0
# IDOTRR        100123.783784  103000.0
# MeadowV        98576.470588   88000.0
# Mitchel       156270.122449  153500.0
# NAmes         145847.080000  140000.0
# NPkVill       142694.444444  146000.0
# NWAmes        189050.068493  182900.0
# NoRidge       335295.317073  301500.0
# NridgHt       316270.623377  315000.0
# OldTown       128225.300885  119000.0
# SWISU         142591.360000  139500.0
# Sawyer        136793.135135  135000.0
# SawyerW       186555.796610  179900.0
# Somerst       225379.837209  225500.0
# StoneBr       310499.000000  278000.0
# Timber        242247.447368  228475.0
# Veenker       238772.727273  218000.0

# %%
# Sort the dataset by Price_Per_SqFt
house_prices_df.sort_values(by='Price_Per_SqFt', ascending=False, inplace=True)

house_prices_df.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 688    689          20       RL         60.0     8089   Pave  Grvl      Reg
# 898    899          20       RL        100.0    12919   Pave  Grvl      IR1
# 1181  1182         120       RM         64.0     5587   Pave  Grvl      IR1
# 440    441          20       RL        105.0    15431   Pave  Grvl      Reg
# 178    179          20       RL         63.0    17423   Pave  Grvl      IR1
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 688          HLS    AllPub  ...     Gd  MnPrv        Shed       0     10
# 898          Lvl    AllPub  ...     Gd  MnPrv        Shed       0      3
# 1181         HLS    AllPub  ...     Gd  MnPrv        Shed       0     11
# 440          Lvl    AllPub  ...     Gd  MnPrv        Shed       0      4
# 178          Lvl    AllPub  ...     Gd  MnPrv        Shed       0      7
#
#      YrSold SaleType  SaleCondition  SalePrice  Price_Per_SqFt
# 688    2007      New        Partial     392000      276.250881
# 898    2010      New        Partial     611657      258.738156
# 1181   2008      New        Partial     392500      237.590799
# 440    2009       WD         Normal     555000      231.057452
# 178    2009      New        Partial     501837      224.636079
#
# [5 rows x 82 columns]

# %% [markdown]
# ### **Problem 3: Handling Missing Data and Imputation**
# 1. Identify columns with **missing values**.
# 2. Impute the missing values:
#    - For **numerical columns**, replace missing values with the **median**.
#    - For **categorical columns**, replace missing values with the **most frequent** value.
# 3. Justify your choice of imputation methods and check if any missing data remains.

# %%
missing_values = house_prices_df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
# Numerical columns -> fill with median
num_cols = house_prices_df.select_dtypes(include=['number']).columns
house_prices_df[num_cols] = house_prices_df[num_cols].fillna(
    house_prices_df[num_cols].median()
)

# Categorical columns -> fill with most frequent value (mode)
cat_cols = house_prices_df.select_dtypes(include=['str']).columns
house_prices_df[cat_cols] = house_prices_df[cat_cols].fillna(
    house_prices_df[cat_cols].mode().iloc[0]
)

# %%
remaining_missing = house_prices_df.isnull().sum()
remaining_missing = remaining_missing[remaining_missing > 0]

print("\nRemaining missing values after imputation:")
print(remaining_missing)
# Out:
# Remaining missing values after imputation:
# Series([], dtype: int64)

# %% [markdown]
# ### **Problem 4: Numpy Array Operations**
# 1. Convert the numerical columns (such as `LotArea`, `YearBuilt`, `GrLivArea`, `SalePrice`, etc.) into a **NumPy array**.
# 2. Perform the following NumPy operations on the array:
#    - Compute the **mean** and **standard deviation** of each column.
#    - Normalize the data using **min-max scaling** and **z-score normalization**.
#    - Compute the **dot product** between two numerical columns of your choice.

# %%
num_df = house_prices_df.select_dtypes(include=['number'])

num_array = num_df.to_numpy()

print("NumPy Array Shape:")
print(num_array.shape)
# Out:
# NumPy Array Shape:
# (1460, 39)

# %%
import numpy as np

# Mean of each column
column_means = np.mean(num_array, axis=0)

# Standard deviation of each column
column_std = np.std(num_array, axis=0)

print("\nColumn Means:")
print(column_means)

print("\nColumn Standard Deviations:")
print(column_std)
# Out:
# Column Means:
# [7.30500000e+02 5.68972603e+01 6.98636986e+01 1.05168281e+04
#  6.09931507e+00 5.57534247e+00 1.97126781e+03 1.98486575e+03
#  1.03117123e+02 4.43639726e+02 4.65493151e+01 5.67240411e+02
#  1.05742945e+03 1.16262671e+03 3.46992466e+02 5.84452055e+00
#  1.51546370e+03 4.25342466e-01 5.75342466e-02 1.56506849e+00
#  3.82876712e-01 2.86643836e+00 1.04657534e+00 6.51780822e+00
#  6.13013699e-01 1.97858904e+03 1.76712329e+00 4.72980137e+02
#  9.42445205e+01 4.66602740e+01 2.19541096e+01 3.40958904e+00
#  1.50609589e+01 2.75890411e+00 4.34890411e+01 6.32191781e+00
#  2.00781575e+03 1.80921196e+05 1.20572878e+02]
#
# Column Standard Deviations:
# [4.21465598e+02 4.22860820e+01 2.20201321e+01 9.97784611e+03
#  1.38252284e+00 1.11241818e+00 3.01925588e+01 2.06383353e+01
#  1.80669468e+02 4.55941866e+02 1.61264017e+02 4.41715605e+02
#  4.38555057e+02 3.86455322e+02 4.36378914e+02 4.86064268e+01
#  5.25300394e+02 5.18732867e-01 2.38670868e-01 5.50727099e-01
#  5.02713131e-01 8.15498620e-01 2.20262727e-01 1.62483655e+00
#  6.44445572e-01 2.39888020e+01 7.47059036e-01 2.13731608e+02
#  1.25295863e+02 6.62333334e+01 6.10982138e+01 2.93072887e+01
#  5.57383170e+01 4.01635452e+01 4.95953090e+02 2.70270015e+00
#  1.32764022e+00 7.94152919e+04 3.13803285e+01]

# %%
# Min-Max Scaling
min_max_scaled = (num_array - np.min(num_array, axis=0)) / (
    np.max(num_array, axis=0) - np.min(num_array, axis=0)
)

print("\nMin-Max Scaled Data:")
print(min_max_scaled)
# Out:
# Min-Max Scaled Data:
# [[0.47155586 0.         0.13356164 ... 0.25       0.49590335 1.        ]
#  [0.61549006 0.         0.27054795 ... 1.         0.80094015 0.92935345]
#  [0.80945853 0.58823529 0.14726027 ... 0.5        0.49659769 0.84404475]
#  ...
#  [0.72789582 1.         0.21917808 ... 0.25       0.07651715 0.04095399]
#  [0.02056203 0.29411765 0.09931507 ... 0.5        0.00708235 0.00812176]
#  [0.88965045 0.23529412 1.         ... 0.5        0.17372587 0.        ]]

# %%
# Z-Score Normalization
z_score_normalized = (num_array - np.mean(num_array, axis=0)) / np.std(num_array, axis=0)

print("\nZ-Score Normalized Data:")
print(z_score_normalized)
# Out:
# Z-Score Normalized Data:
# [[-0.09846593 -0.87256276 -0.44794003 ... -0.61443862  2.65791133
#    4.96100615]
#  [ 0.39979538 -0.87256276  1.3685795  ...  1.64520971  5.42383959
#    4.40292642]
#  [ 1.07126181  1.49228154 -0.26628808 ...  0.13877749  2.66420735
#    3.72902154]
#  ...
#  [ 0.78891374  3.14767255  0.68738468 ... -0.61443862 -1.14488273
#   -2.61507672]
#  [-1.65968469  0.30985939 -0.90206991 ...  0.13877749 -1.77448439
#   -2.87443837]
#  [ 1.34886454  0.07337496 11.04154601 ...  0.13877749 -0.2634404
#   -2.93859702]]

# %%
# Dot Product between two numerical columns
lotarea = house_prices_df['LotArea'].to_numpy()
saleprice = house_prices_df['SalePrice'].to_numpy()

dot_product = np.dot(lotarea, saleprice)

print("\nDot Product of LotArea and SalePrice:")
print(dot_product)
# Out:
# Z-Score Normalized Data:
# [[-0.09846593 -0.87256276 -0.44794003 ... -0.61443862  2.65791133
#    4.96100615]
#  [ 0.39979538 -0.87256276  1.3685795  ...  1.64520971  5.42383959
#    4.40292642]
#  [ 1.07126181  1.49228154 -0.26628808 ...  0.13877749  2.66420735
#    3.72902154]
#  ...
#  [ 0.78891374  3.14767255  0.68738468 ... -0.61443862 -1.14488273
#   -2.61507672]
#  [-1.65968469  0.30985939 -0.90206991 ...  0.13877749 -1.77448439
#   -2.87443837]
#  [ 1.34886454  0.07337496 11.04154601 ...  0.13877749 -0.2634404
#   -2.93859702]]

# %% [markdown]
# ### **Problem 5: Data Visualization**
# Using Matplotlib and/or Seaborn, visualize the following:
# 1. **Distribution** of `SalePrice` using a **histogram**.
# 2. **Box plot** of `SalePrice` grouped by `OverallQual` (overall quality of the house).
# 3. **Scatter plot** between `GrLivArea` (Above-ground living area) and `SalePrice`. Analyze the relationship.
# 4. Plot a **correlation heatmap** for the numerical columns.

# %%
plt.figure(figsize=(8, 5))
plt.hist(house_prices_df['SalePrice'], bins=30)
plt.title('Distribution of SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='OverallQual', y='SalePrice', data=house_prices_df)
plt.title('SalePrice by Overall Quality')
plt.xlabel('Overall Quality')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(house_prices_df['GrLivArea'], house_prices_df['SalePrice'])
plt.title('GrLivArea vs SalePrice')
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# %%
num_df = house_prices_df.select_dtypes(include=['number'])

plt.figure(figsize=(14, 10))
sns.heatmap(num_df.corr(), cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### **Problem 6: Aggregation and Transformation**
# 1. Perform a **groupby** operation on `Neighborhood` and calculate the **mean** and **median** for `SalePrice`.
# 2. Use the `apply()` function to create a custom transformation for `SalePrice` (e.g., scaling or transformation).
# 3. Aggregate multiple statistical values (e.g., **mean**, **median**, and **count**) for `SalePrice` grouped by `OverallQual`.

# %%
neighborhood_stats = house_prices_df.groupby('Neighborhood')['SalePrice'].agg(
    ['mean', 'median']
)

print("Mean and Median SalePrice by Neighborhood:")
print(neighborhood_stats)
# Out:
# Mean and Median SalePrice by Neighborhood:
#                        mean    median
# Neighborhood
# Blmngtn       194870.882353  191000.0
# Blueste       137500.000000  137500.0
# BrDale        104493.750000  106000.0
# BrkSide       124834.051724  124300.0
# ClearCr       212565.428571  200250.0
# CollgCr       197965.773333  197200.0
# Crawfor       210624.725490  200624.0
# Edwards       128219.700000  121750.0
# Gilbert       192854.506329  181000.0
# IDOTRR        100123.783784  103000.0
# MeadowV        98576.470588   88000.0
# Mitchel       156270.122449  153500.0
# NAmes         145847.080000  140000.0
# NPkVill       142694.444444  146000.0
# NWAmes        189050.068493  182900.0
# NoRidge       335295.317073  301500.0
# NridgHt       316270.623377  315000.0
# OldTown       128225.300885  119000.0
# SWISU         142591.360000  139500.0
# Sawyer        136793.135135  135000.0
# SawyerW       186555.796610  179900.0
# Somerst       225379.837209  225500.0
# StoneBr       310499.000000  278000.0
# Timber        242247.447368  228475.0
# Veenker       238772.727273  218000.0

# %%
house_prices_df['SalePrice_Scaled'] = house_prices_df['SalePrice'].apply(
    lambda x: (
        (x - house_prices_df['SalePrice'].min()) /
        (house_prices_df['SalePrice'].max() - house_prices_df['SalePrice'].min())
    )
)

print("\nScaled SalePrice:")
print(house_prices_df[['SalePrice', 'SalePrice_Scaled']].head())
# Out:
# Scaled SalePrice:
#       SalePrice  SalePrice_Scaled
# 688      392000          0.495903
# 898      611657          0.800940
# 1181     392500          0.496598
# 440      555000          0.722261
# 178      501837          0.648434

# %%
overallqual_stats = house_prices_df.groupby('OverallQual')['SalePrice'].agg(
    ['mean', 'median', 'count']
)

print("\nSalePrice Statistics by OverallQual:")
print(overallqual_stats)
# Out:
# SalePrice Statistics by OverallQual:
#                       mean    median  count
# OverallQual
# 1             50150.000000   50150.0      2
# 2             51770.333333   60000.0      3
# 3             87473.750000   86250.0     20
# 4            108420.655172  108000.0    116
# 5            133523.347607  133000.0    397
# 6            161603.034759  160000.0    374
# 7            207716.423197  200141.0    319
# 8            274735.535714  269750.0    168
# 9            367513.023256  345000.0     43
# 10           438588.388889  432390.0     18
